# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"

# %%
import time
import numpy as np
import pandas as pd
import openpyxl

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score

# ✅ Allowed faster SVM
from sklearn.svm import LinearSVC

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# %%
# Paths
DATA_ROOT = "Datasets"
RESULTS_XLSX = "/Users/classroomservices/Desktop/Winter/Machine Learning/Project/Code/Datasets/Results.xlsx"
OUT_PHASE1 = "Results_BEFORE_filled.xlsx"

LABEL_COL = "Label"
RANDOM_STATE = 42

# REQUIRED outer folds for the assignment
OUTER_FOLDS_DEFAULT = 10

# ✅ According to email:
# - Keep 10-fold normally
# - If SVM still too slow, you may set SVM only to 5 folds
SVM_OUTER_FOLDS = 10   # change to 5 ONLY if needed (must mention in report)

# Inner CV for tuning (not fixed in email; keep 3 for speed)
INNER_FOLDS = 3
inner_cv = StratifiedKFold(n_splits=INNER_FOLDS, shuffle=True, random_state=RANDOM_STATE)

# n_jobs stability for nested CV on Mac
N_JOBS = 1

# %%
import os

def load_one_dataset(dataset_id: int):
    """
    Loads Datasets/<id>/train.csv + test.csv and combines them.
    This ensures 10-fold StratifiedKFold works for all datasets.
    """
    train_path = os.path.join(DATA_ROOT, str(dataset_id), "train.csv")
    test_path  = os.path.join(DATA_ROOT, str(dataset_id), "test.csv")

    df = pd.concat([pd.read_csv(train_path), pd.read_csv(test_path)], ignore_index=True)

    if LABEL_COL not in df.columns:
        raise ValueError(f"'{LABEL_COL}' not found in dataset {dataset_id}")

    X = df.drop(columns=[LABEL_COL])
    y = pd.Series(pd.factorize(df[LABEL_COL])[0], index=df.index)
    return X, y

# %%
def get_model_and_grid(clf_name: str):
    """
    Returns model + grid for GridSearchCV.
    Email says: reduce grid OR use LinearSVC.
    We'll use LinearSVC for SVM and keep grids reasonable for others.
    """

    if clf_name == "SVM":
        # ✅ Fast SVM (allowed by email)
        model = LinearSVC(dual="auto", max_iter=20000,tol=1e-3, random_state=RANDOM_STATE)
        grid = {
            "clf__C": [0.01, 0.1, 1, 10]
        }
        return model, grid

    if clf_name == "KNN":
        model = KNeighborsClassifier()
        grid = {
            "clf__n_neighbors": [3, 5, 7, 9, 11],
            "clf__weights": ["uniform", "distance"]
        }
        return model, grid

    if clf_name == "DT":
        model = DecisionTreeClassifier(random_state=RANDOM_STATE)
        grid = {
            "clf__max_depth": [None, 5, 10, 20],
            "clf__min_samples_split": [2, 5, 10]
        }
        return model, grid

    if clf_name == "RF":
        model = RandomForestClassifier(random_state=RANDOM_STATE)
        grid = {
            "clf__n_estimators": [100, 200],
            "clf__max_depth": [None, 10, 20]
        }
        return model, grid

    if clf_name == "MLP":
        model = MLPClassifier(
            max_iter=300,
            early_stopping=True,
            n_iter_no_change=10,
            random_state=RANDOM_STATE
        )
        grid = {
            "clf__hidden_layer_sizes": [(50,), (100,), (50, 50)],
            "clf__alpha": [1e-4, 1e-3, 1e-2]
        }
        return model, grid

    raise ValueError("Unknown classifier: " + clf_name)

# %%
def format_params(best_params: dict, prefix="clf__"):
    parts = []
    for k, v in best_params.items():
        if k.startswith(prefix):
            parts.append(f"{k.replace(prefix,'')}={v}")
    return "; ".join(parts)

# %%
def run_baseline_one_classifier(dataset_id: int, clf_name: str):
    """
    Phase 1 pipeline:
      Imputer -> Scaler -> Classifier

    Outer CV:
      - normally 10 folds
      - but if clf_name == 'SVM' and SVM_OUTER_FOLDS == 5, then SVM uses 5 folds only (email allowed)
    """
    X, y = load_one_dataset(dataset_id)
    model, grid = get_model_and_grid(clf_name)

    # choose outer folds for this classifier
    outer_folds = OUTER_FOLDS_DEFAULT
    if clf_name == "SVM" and SVM_OUTER_FOLDS == 5:
        outer_folds = 5
        print("⚠️ Using 5-fold OUTER CV for SVM ONLY (allowed by email). Must justify in report.")

    outer_cv_local = StratifiedKFold(n_splits=outer_folds, shuffle=True, random_state=RANDOM_STATE)

    pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
        ("clf", model)
    ])

    fold_rows = []
    print(f"\n✅ Phase 1 | Data {dataset_id} | {clf_name} | outer_folds={outer_folds}")

    for fold_idx, (tr_idx, va_idx) in enumerate(outer_cv_local.split(X, y), start=1):
        print(f"➡️ {clf_name} Fold {fold_idx}/{outer_folds} ...")

        X_tr, X_va = X.iloc[tr_idx], X.iloc[va_idx]
        y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]

        gs = GridSearchCV(
            estimator=pipe,
            param_grid=grid,
            scoring="f1_macro",
            cv=inner_cv,
            n_jobs=N_JOBS,
            refit=True
        )

        t0 = time.time()
        gs.fit(X_tr, y_tr)
        fit_t = time.time() - t0

        y_pred = gs.predict(X_va)
        acc = accuracy_score(y_va, y_pred)
        f1m = f1_score(y_va, y_pred, average="macro")

        print(f"✅ Done | Acc={acc:.4f} F1={f1m:.4f} | fit={fit_t:.1f}s")

        fold_rows.append({
            "fold": fold_idx,
            "accuracy": float(acc),
            "f1_macro": float(f1m),
            "params_str": format_params(gs.best_params_, "clf__")
        })

    return fold_rows, outer_folds

# %%
def dataset_block_start_row(dataset_id: int) -> int:
    return 1 + (dataset_id - 1) * 12

def fold_row(dataset_id: int, fold_idx: int) -> int:
    return dataset_block_start_row(dataset_id) + 2 + (fold_idx - 1)

def write_before_sheet(ws_before, dataset_id: int, results: dict, outer_folds_map: dict):
    """
    Writes folds into Before sheet.
    If SVM uses only 5 folds, we fill Fold1..Fold5 and leave Fold6..Fold10 empty for SVM columns.
    Other classifiers always fill 10 folds.
    """
    clfs = ["SVM", "KNN", "DT", "RF", "MLP"]

    for f in range(1, 11):
        r = fold_row(dataset_id, f)

        col = 2  # B
        for clf in clfs:
            folds_used = outer_folds_map[clf]
            if f <= folds_used:
                row = results[clf][f-1]
                ws_before.cell(row=r, column=col).value   = round(row["accuracy"], 4)
                ws_before.cell(row=r, column=col+1).value = round(row["f1_macro"], 4)
            # else: leave blank
            col += 2

        # Params L..P
        colp = 12
        for clf in clfs:
            folds_used = outer_folds_map[clf]
            if f <= folds_used:
                ws_before.cell(row=r, column=colp).value = results[clf][f-1]["params_str"]
            colp += 1

# %%
wb = openpyxl.load_workbook(RESULTS_XLSX)
ws_before = wb["Before FS-DR"]

clfs = ["SVM", "KNN", "DT", "RF", "MLP"]

for dataset_id in range(1, 17):
    print(f"\n================ PHASE 1 | DATA {dataset_id} ================")

    results = {}
    outer_folds_map = {}

    for clf in clfs:
        rows, used_folds = run_baseline_one_classifier(dataset_id, clf)
        results[clf] = rows
        outer_folds_map[clf] = used_folds

    write_before_sheet(ws_before, dataset_id, results, outer_folds_map)

    wb.save(OUT_PHASE1)
    print("✅ Saved checkpoint:", OUT_PHASE1)

print("\n✅ Phase 1 complete:", OUT_PHASE1)
# Out:
# ================ PHASE 1 | DATA 1 ================
#
# ✅ Phase 1 | Data 1 | SVM | outer_folds=10
# ➡️ SVM Fold 1/10 ...
# ✅ Done | Acc=0.9789 F1=0.7291 | fit=0.4s
# ➡️ SVM Fold 2/10 ...
# ✅ Done | Acc=0.9765 F1=0.9694 | fit=0.3s
# ➡️ SVM Fold 3/10 ...
# ✅ Done | Acc=0.9812 F1=0.7285 | fit=0.4s
# ➡️ SVM Fold 4/10 ...
# ✅ Done | Acc=0.9789 F1=0.9783 | fit=0.4s
# ➡️ SVM Fold 5/10 ...
# ✅ Done | Acc=0.9812 F1=0.9809 | fit=0.3s
# ➡️ SVM Fold 6/10 ...
# ✅ Done | Acc=0.9804 F1=0.9769 | fit=0.3s
# ➡️ SVM Fold 7/10 ...
# ✅ Done | Acc=0.9851 F1=0.7321 | fit=0.4s
# ➡️ SVM Fold 8/10 ...
# ✅ Done | Acc=0.9890 F1=0.9859 | fit=0.4s
# ➡️ SVM Fold 9/10 ...
# ✅ Done | Acc=0.9773 F1=0.7242 | fit=0.3s
# ➡️ SVM Fold 10/10 ...
# ✅ Done | Acc=0.9804 F1=0.9800 | fit=0.4s
#
# ✅ Phase 1 | Data 1 | KNN | outer_folds=10
# ➡️ KNN Fold 1/10 ...
# ✅ Done | Acc=0.9937 F1=0.7413 | fit=2.0s
# ➡️ KNN Fold 2/10 ...
# ✅ Done | Acc=0.9883 F1=0.9756 | fit=2.0s
# ➡️ KNN Fold 3/10 ...
# ✅ Done | Acc=0.9789 F1=0.7201 | fit=2.0s
# ➡️ KNN Fold 4/10 ...
# ✅ Done | Acc=0.9875 F1=0.7204 | fit=1.9s
# ➡️ KNN Fold 5/10 ...
# ✅ Done | Acc=0.9898 F1=0.7407 | fit=2.0s
# ➡️ KNN Fold 6/10 ...
# ✅ Done | Acc=0.9828 F1=0.8529 | fit=2.0s
# ➡️ KNN Fold 7/10 ...
# ✅ Done | Acc=0.9883 F1=0.7212 | fit=2.0s
# ➡️ KNN Fold 8/10 ...
# ✅ Done | Acc=0.9883 F1=0.9854 | fit=2.0s
# ➡️ KNN Fold 9/10 ...
# ✅ Done | Acc=0.9883 F1=0.7326 | fit=2.0s
# ➡️ KNN Fold 10/10 ...
# ✅ Done | Acc=0.9867 F1=0.9839 | fit=2.0s
#
# ✅ Phase 1 | Data 1 | DT | outer_folds=10
# ➡️ DT Fold 1/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 2/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 3/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 4/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 5/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 6/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 7/10 ...
# ✅ Done | Acc=0.9992 F1=0.7463 | fit=0.5s
# ➡️ DT Fold 8/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 9/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 10/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
#
# ✅ Phase 1 | Data 1 | RF | outer_folds=10
# ➡️ RF Fold 1/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.0s
# ➡️ RF Fold 2/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 3/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.0s
# ➡️ RF Fold 4/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.3s
# ➡️ RF Fold 5/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.0s
# ➡️ RF Fold 6/10 ...
# ✅ Done | Acc=0.9992 F1=0.9992 | fit=5.2s
# ➡️ RF Fold 7/10 ...
# ✅ Done | Acc=0.9992 F1=0.7463 | fit=5.2s
# ➡️ RF Fold 8/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.0s
# ➡️ RF Fold 9/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.0s
# ➡️ RF Fold 10/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.3s
#
# ✅ Phase 1 | Data 1 | MLP | outer_folds=10
# ➡️ MLP Fold 1/10 ...
# ✅ Done | Acc=0.9836 F1=0.7280 | fit=9.4s
# ➡️ MLP Fold 2/10 ...
# ✅ Done | Acc=0.9797 F1=0.9667 | fit=10.0s
# ➡️ MLP Fold 3/10 ...
# ✅ Done | Acc=0.9867 F1=0.7307 | fit=9.4s
# ➡️ MLP Fold 4/10 ...
# ✅ Done | Acc=0.9789 F1=0.9753 | fit=8.6s
# ➡️ MLP Fold 5/10 ...
# ✅ Done | Acc=0.9836 F1=0.7341 | fit=11.6s
# ➡️ MLP Fold 6/10 ...
# ✅ Done | Acc=0.9734 F1=0.9662 | fit=9.7s
# ➡️ MLP Fold 7/10 ...
# ✅ Done | Acc=0.9820 F1=0.7257 | fit=10.0s
# ➡️ MLP Fold 8/10 ...
# ✅ Done | Acc=0.9750 F1=0.7187 | fit=8.8s
# ➡️ MLP Fold 9/10 ...
# ✅ Done | Acc=0.9843 F1=0.7285 | fit=9.5s
# ➡️ MLP Fold 10/10 ...
# ✅ Done | Acc=0.9867 F1=0.9867 | fit=10.2s
# ✅ Saved checkpoint: Results_BEFORE_filled.xlsx
#
# ================ PHASE 1 | DATA 2 ================
#
# ✅ Phase 1 | Data 2 | SVM | outer_folds=10
# ➡️ SVM Fold 1/10 ...
# ✅ Done | Acc=0.9038 F1=0.4013 | fit=0.3s
# ➡️ SVM Fold 2/10 ...
# ✅ Done | Acc=0.9085 F1=0.4092 | fit=0.3s
# ➡️ SVM Fold 3/10 ...
# ✅ Done | Acc=0.9038 F1=0.4031 | fit=0.3s
# ➡️ SVM Fold 4/10 ...
# ✅ Done | Acc=0.8991 F1=0.3928 | fit=0.3s
# ➡️ SVM Fold 5/10 ...
# ✅ Done | Acc=0.8998 F1=0.3943 | fit=0.3s
# ➡️ SVM Fold 6/10 ...
# ✅ Done | Acc=0.9038 F1=0.4015 | fit=0.3s
# ➡️ SVM Fold 7/10 ...
# ✅ Done | Acc=0.9006 F1=0.3960 | fit=0.3s
# ➡️ SVM Fold 8/10 ...
# ✅ Done | Acc=0.9014 F1=0.3983 | fit=0.3s
# ➡️ SVM Fold 9/10 ...
# ✅ Done | Acc=0.9029 F1=0.3996 | fit=0.3s
# ➡️ SVM Fold 10/10 ...
# ✅ Done | Acc=0.9052 F1=0.4029 | fit=0.3s
#
# ✅ Phase 1 | Data 2 | KNN | outer_folds=10
# ➡️ KNN Fold 1/10 ...
# ✅ Done | Acc=0.9531 F1=0.5740 | fit=2.0s
# ➡️ KNN Fold 2/10 ...
# ✅ Done | Acc=0.9593 F1=0.6160 | fit=2.0s
# ➡️ KNN Fold 3/10 ...
# ✅ Done | Acc=0.9546 F1=0.6374 | fit=2.0s
# ➡️ KNN Fold 4/10 ...
# ✅ Done | Acc=0.9538 F1=0.5423 | fit=2.0s
# ➡️ KNN Fold 5/10 ...
# ✅ Done | Acc=0.9507 F1=0.6129 | fit=2.0s
# ➡️ KNN Fold 6/10 ...
# ✅ Done | Acc=0.9499 F1=0.5331 | fit=2.0s
# ➡️ KNN Fold 7/10 ...
# ✅ Done | Acc=0.9531 F1=0.5579 | fit=2.0s
# ➡️ KNN Fold 8/10 ...
# ✅ Done | Acc=0.9515 F1=0.6080 | fit=2.0s
# ➡️ KNN Fold 9/10 ...
# ✅ Done | Acc=0.9554 F1=0.6038 | fit=2.0s
# ➡️ KNN Fold 10/10 ...
# ✅ Done | Acc=0.9648 F1=0.6299 | fit=2.0s
#
# ✅ Phase 1 | Data 2 | DT | outer_folds=10
# ➡️ DT Fold 1/10 ...
# ✅ Done | Acc=0.9538 F1=0.5595 | fit=0.6s
# ➡️ DT Fold 2/10 ...
# ✅ Done | Acc=0.9601 F1=0.5891 | fit=0.6s
# ➡️ DT Fold 3/10 ...
# ✅ Done | Acc=0.9617 F1=0.6094 | fit=0.6s
# ➡️ DT Fold 4/10 ...
# ✅ Done | Acc=0.9585 F1=0.6096 | fit=0.6s
# ➡️ DT Fold 5/10 ...
# ✅ Done | Acc=0.9570 F1=0.5300 | fit=0.6s
# ➡️ DT Fold 6/10 ...
# ✅ Done | Acc=0.9515 F1=0.5273 | fit=0.6s
# ➡️ DT Fold 7/10 ...
# ✅ Done | Acc=0.9593 F1=0.5732 | fit=0.6s
# ➡️ DT Fold 8/10 ...
# ✅ Done | Acc=0.9554 F1=0.5819 | fit=0.6s
# ➡️ DT Fold 9/10 ...
# ✅ Done | Acc=0.9608 F1=0.5231 | fit=0.6s
# ➡️ DT Fold 10/10 ...
# ✅ Done | Acc=0.9671 F1=0.5914 | fit=0.6s
#
# ✅ Phase 1 | Data 2 | RF | outer_folds=10
# ➡️ RF Fold 1/10 ...
# ✅ Done | Acc=0.9585 F1=0.5723 | fit=6.1s
# ➡️ RF Fold 2/10 ...
# ✅ Done | Acc=0.9632 F1=0.5950 | fit=6.1s
# ➡️ RF Fold 3/10 ...
# ✅ Done | Acc=0.9577 F1=0.5369 | fit=6.1s
# ➡️ RF Fold 4/10 ...
# ✅ Done | Acc=0.9593 F1=0.5217 | fit=5.8s
# ➡️ RF Fold 5/10 ...
# ✅ Done | Acc=0.9624 F1=0.5823 | fit=6.2s
# ➡️ RF Fold 6/10 ...
# ✅ Done | Acc=0.9546 F1=0.5396 | fit=5.8s
# ➡️ RF Fold 7/10 ...
# ✅ Done | Acc=0.9632 F1=0.5871 | fit=5.8s
# ➡️ RF Fold 8/10 ...
# ✅ Done | Acc=0.9593 F1=0.5744 | fit=5.9s
# ➡️ RF Fold 9/10 ...
# ✅ Done | Acc=0.9616 F1=0.6387 | fit=6.1s
# ➡️ RF Fold 10/10 ...
# ✅ Done | Acc=0.9695 F1=0.6626 | fit=6.1s
#
# ✅ Phase 1 | Data 2 | MLP | outer_folds=10
# ➡️ MLP Fold 1/10 ...
# ✅ Done | Acc=0.9374 F1=0.4486 | fit=7.4s
# ➡️ MLP Fold 2/10 ...
# ✅ Done | Acc=0.9499 F1=0.5054 | fit=6.3s
# ➡️ MLP Fold 3/10 ...
# ✅ Done | Acc=0.9437 F1=0.5585 | fit=7.1s
# ➡️ MLP Fold 4/10 ...
# ✅ Done | Acc=0.9468 F1=0.5031 | fit=7.5s
# ➡️ MLP Fold 5/10 ...
# ✅ Done | Acc=0.9397 F1=0.4884 | fit=7.5s
# ➡️ MLP Fold 6/10 ...
# ✅ Done | Acc=0.9437 F1=0.5276 | fit=7.9s
# ➡️ MLP Fold 7/10 ...
# ✅ Done | Acc=0.9538 F1=0.5434 | fit=8.4s
# ➡️ MLP Fold 8/10 ...
# ✅ Done | Acc=0.9413 F1=0.5468 | fit=7.7s
# ➡️ MLP Fold 9/10 ...
# ✅ Done | Acc=0.9397 F1=0.5529 | fit=8.1s
# ➡️ MLP Fold 10/10 ...
# ✅ Done | Acc=0.9561 F1=0.5725 | fit=8.5s
# ✅ Saved checkpoint: Results_BEFORE_filled.xlsx
#
# ================ PHASE 1 | DATA 3 ================
#
# ✅ Phase 1 | Data 3 | SVM | outer_folds=10
# ➡️ SVM Fold 1/10 ...
# ✅ Done | Acc=0.8474 F1=0.2911 | fit=0.3s
# ➡️ SVM Fold 2/10 ...
# ✅ Done | Acc=0.8529 F1=0.3107 | fit=0.3s
# ➡️ SVM Fold 3/10 ...
# ✅ Done | Acc=0.8482 F1=0.2891 | fit=0.3s
# ➡️ SVM Fold 4/10 ...
# ✅ Done | Acc=0.8505 F1=0.3157 | fit=0.3s
# ➡️ SVM Fold 5/10 ...
# ✅ Done | Acc=0.8521 F1=0.3123 | fit=0.3s
# ➡️ SVM Fold 6/10 ...
# ✅ Done | Acc=0.8443 F1=0.2977 | fit=0.3s
# ➡️ SVM Fold 7/10 ...
# ✅ Done | Acc=0.8513 F1=0.3094 | fit=0.3s
# ➡️ SVM Fold 8/10 ...
# ✅ Done | Acc=0.8545 F1=0.3156 | fit=0.3s
# ➡️ SVM Fold 9/10 ...
# ✅ Done | Acc=0.8504 F1=0.2990 | fit=0.3s
# ➡️ SVM Fold 10/10 ...
# ✅ Done | Acc=0.8520 F1=0.3136 | fit=0.3s
#
# ✅ Phase 1 | Data 3 | KNN | outer_folds=10
# ➡️ KNN Fold 1/10 ...
# ✅ Done | Acc=0.8858 F1=0.5123 | fit=2.0s
# ➡️ KNN Fold 2/10 ...
# ✅ Done | Acc=0.8756 F1=0.5055 | fit=2.0s
# ➡️ KNN Fold 3/10 ...
# ✅ Done | Acc=0.8889 F1=0.5621 | fit=2.0s
# ➡️ KNN Fold 4/10 ...
# ✅ Done | Acc=0.8818 F1=0.5360 | fit=2.0s
# ➡️ KNN Fold 5/10 ...
# ✅ Done | Acc=0.8748 F1=0.5134 | fit=2.0s
# ➡️ KNN Fold 6/10 ...
# ✅ Done | Acc=0.8764 F1=0.5263 | fit=2.0s
# ➡️ KNN Fold 7/10 ...
# ✅ Done | Acc=0.8873 F1=0.5357 | fit=2.0s
# ➡️ KNN Fold 8/10 ...
# ✅ Done | Acc=0.8881 F1=0.5261 | fit=2.0s
# ➡️ KNN Fold 9/10 ...
# ✅ Done | Acc=0.8912 F1=0.5636 | fit=2.0s
# ➡️ KNN Fold 10/10 ...
# ✅ Done | Acc=0.8896 F1=0.5726 | fit=2.0s
#
# ✅ Phase 1 | Data 3 | DT | outer_folds=10
# ➡️ DT Fold 1/10 ...
# ✅ Done | Acc=0.8991 F1=0.5470 | fit=0.7s
# ➡️ DT Fold 2/10 ...
# ✅ Done | Acc=0.8787 F1=0.5111 | fit=0.7s
# ➡️ DT Fold 3/10 ...
# ✅ Done | Acc=0.8842 F1=0.5150 | fit=0.7s
# ➡️ DT Fold 4/10 ...
# ✅ Done | Acc=0.8779 F1=0.5228 | fit=0.7s
# ➡️ DT Fold 5/10 ...
# ✅ Done | Acc=0.8740 F1=0.5228 | fit=0.7s
# ➡️ DT Fold 6/10 ...
# ✅ Done | Acc=0.8826 F1=0.5546 | fit=0.7s
# ➡️ DT Fold 7/10 ...
# ✅ Done | Acc=0.8912 F1=0.5547 | fit=0.7s
# ➡️ DT Fold 8/10 ...
# ✅ Done | Acc=0.8811 F1=0.4986 | fit=0.7s
# ➡️ DT Fold 9/10 ...
# ✅ Done | Acc=0.8872 F1=0.5592 | fit=0.7s
# ➡️ DT Fold 10/10 ...
# ✅ Done | Acc=0.8653 F1=0.4908 | fit=0.7s
#
# ✅ Phase 1 | Data 3 | RF | outer_folds=10
# ➡️ RF Fold 1/10 ...
# ✅ Done | Acc=0.8951 F1=0.5400 | fit=7.8s
# ➡️ RF Fold 2/10 ...
# ✅ Done | Acc=0.8787 F1=0.4987 | fit=7.4s
# ➡️ RF Fold 3/10 ...
# ✅ Done | Acc=0.8850 F1=0.5087 | fit=7.4s
# ➡️ RF Fold 4/10 ...
# ✅ Done | Acc=0.8858 F1=0.5508 | fit=7.4s
# ➡️ RF Fold 5/10 ...
# ✅ Done | Acc=0.8811 F1=0.5185 | fit=7.7s
# ➡️ RF Fold 6/10 ...
# ✅ Done | Acc=0.8881 F1=0.5483 | fit=7.2s
# ➡️ RF Fold 7/10 ...
# ✅ Done | Acc=0.8936 F1=0.5630 | fit=7.1s
# ➡️ RF Fold 8/10 ...
# ✅ Done | Acc=0.8967 F1=0.5465 | fit=7.7s
# ➡️ RF Fold 9/10 ...
# ✅ Done | Acc=0.8958 F1=0.5922 | fit=7.4s
# ➡️ RF Fold 10/10 ...
# ✅ Done | Acc=0.8786 F1=0.5257 | fit=7.7s
#
# ✅ Phase 1 | Data 3 | MLP | outer_folds=10
# ➡️ MLP Fold 1/10 ...
# ✅ Done | Acc=0.8912 F1=0.5267 | fit=7.4s
# ➡️ MLP Fold 2/10 ...
# ✅ Done | Acc=0.8764 F1=0.4282 | fit=7.6s
# ➡️ MLP Fold 3/10 ...
# ✅ Done | Acc=0.8795 F1=0.5060 | fit=6.6s
# ➡️ MLP Fold 4/10 ...
# ✅ Done | Acc=0.8764 F1=0.4991 | fit=7.8s
# ➡️ MLP Fold 5/10 ...
# ✅ Done | Acc=0.8678 F1=0.4548 | fit=7.7s
# ➡️ MLP Fold 6/10 ...
# ✅ Done | Acc=0.8646 F1=0.4636 | fit=6.7s
# ➡️ MLP Fold 7/10 ...
# ✅ Done | Acc=0.8873 F1=0.5374 | fit=8.2s
# ➡️ MLP Fold 8/10 ...
# ✅ Done | Acc=0.8858 F1=0.5002 | fit=6.6s
# ➡️ MLP Fold 9/10 ...
# ✅ Done | Acc=0.8810 F1=0.4994 | fit=7.6s
# ➡️ MLP Fold 10/10 ...
# ✅ Done | Acc=0.8739 F1=0.4711 | fit=7.7s
# ✅ Saved checkpoint: Results_BEFORE_filled.xlsx
#
# ================ PHASE 1 | DATA 4 ================
#
# ✅ Phase 1 | Data 4 | SVM | outer_folds=10
# ➡️ SVM Fold 1/10 ...
# ✅ Done | Acc=0.8451 F1=0.2676 | fit=0.3s
# ➡️ SVM Fold 2/10 ...
# ✅ Done | Acc=0.8459 F1=0.2646 | fit=0.3s
# ➡️ SVM Fold 3/10 ...
# ✅ Done | Acc=0.8388 F1=0.2460 | fit=0.3s
# ➡️ SVM Fold 4/10 ...
# ✅ Done | Acc=0.8459 F1=0.2866 | fit=0.3s
# ➡️ SVM Fold 5/10 ...
# ✅ Done | Acc=0.8443 F1=0.2715 | fit=0.3s
# ➡️ SVM Fold 6/10 ...
# ✅ Done | Acc=0.8412 F1=0.2613 | fit=0.3s
# ➡️ SVM Fold 7/10 ...
# ✅ Done | Acc=0.8443 F1=0.2629 | fit=0.3s
# ➡️ SVM Fold 8/10 ...
# ✅ Done | Acc=0.8427 F1=0.2536 | fit=0.3s
# ➡️ SVM Fold 9/10 ...
# ✅ Done | Acc=0.8465 F1=0.2879 | fit=0.3s
# ➡️ SVM Fold 10/10 ...
# ✅ Done | Acc=0.8442 F1=0.2664 | fit=0.3s
#
# ✅ Phase 1 | Data 4 | KNN | outer_folds=10
# ➡️ KNN Fold 1/10 ...
# ✅ Done | Acc=0.8419 F1=0.4394 | fit=2.0s
# ➡️ KNN Fold 2/10 ...
# ✅ Done | Acc=0.8529 F1=0.4216 | fit=2.0s
# ➡️ KNN Fold 3/10 ...
# ✅ Done | Acc=0.8365 F1=0.4251 | fit=2.0s
# ➡️ KNN Fold 4/10 ...
# ✅ Done | Acc=0.8592 F1=0.4660 | fit=2.0s
# ➡️ KNN Fold 5/10 ...
# ✅ Done | Acc=0.8490 F1=0.4392 | fit=2.0s
# ➡️ KNN Fold 6/10 ...
# ✅ Done | Acc=0.8552 F1=0.4285 | fit=2.0s
# ➡️ KNN Fold 7/10 ...
# ✅ Done | Acc=0.8404 F1=0.4132 | fit=2.0s
# ➡️ KNN Fold 8/10 ...
# ✅ Done | Acc=0.8568 F1=0.4553 | fit=2.0s
# ➡️ KNN Fold 9/10 ...
# ✅ Done | Acc=0.8528 F1=0.4268 | fit=2.0s
# ➡️ KNN Fold 10/10 ...
# ✅ Done | Acc=0.8583 F1=0.4730 | fit=2.0s
#
# ✅ Phase 1 | Data 4 | DT | outer_folds=10
# ➡️ DT Fold 1/10 ...
# ✅ Done | Acc=0.8474 F1=0.4454 | fit=0.7s
# ➡️ DT Fold 2/10 ...
# ✅ Done | Acc=0.8529 F1=0.4225 | fit=0.7s
# ➡️ DT Fold 3/10 ...
# ✅ Done | Acc=0.8427 F1=0.4494 | fit=0.7s
# ➡️ DT Fold 4/10 ...
# ✅ Done | Acc=0.8529 F1=0.4430 | fit=0.7s
# ➡️ DT Fold 5/10 ...
# ✅ Done | Acc=0.8451 F1=0.4525 | fit=0.7s
# ➡️ DT Fold 6/10 ...
# ✅ Done | Acc=0.8537 F1=0.4501 | fit=0.7s
# ➡️ DT Fold 7/10 ...
# ✅ Done | Acc=0.8498 F1=0.4714 | fit=0.7s
# ➡️ DT Fold 8/10 ...
# ✅ Done | Acc=0.8505 F1=0.4378 | fit=0.7s
# ➡️ DT Fold 9/10 ...
# ✅ Done | Acc=0.8512 F1=0.4398 | fit=0.7s
# ➡️ DT Fold 10/10 ...
# ✅ Done | Acc=0.8465 F1=0.4465 | fit=0.7s
#
# ✅ Phase 1 | Data 4 | RF | outer_folds=10
# ➡️ RF Fold 1/10 ...
# ✅ Done | Acc=0.8482 F1=0.4507 | fit=7.8s
# ➡️ RF Fold 2/10 ...
# ✅ Done | Acc=0.8537 F1=0.4216 | fit=7.7s
# ➡️ RF Fold 3/10 ...
# ✅ Done | Acc=0.8435 F1=0.4552 | fit=7.6s
# ➡️ RF Fold 4/10 ...
# ✅ Done | Acc=0.8545 F1=0.4532 | fit=8.1s
# ➡️ RF Fold 5/10 ...
# ✅ Done | Acc=0.8451 F1=0.4260 | fit=7.8s
# ➡️ RF Fold 6/10 ...
# ✅ Done | Acc=0.8584 F1=0.4575 | fit=7.7s
# ➡️ RF Fold 7/10 ...
# ✅ Done | Acc=0.8560 F1=0.4758 | fit=7.8s
# ➡️ RF Fold 8/10 ...
# ✅ Done | Acc=0.8584 F1=0.4688 | fit=7.7s
# ➡️ RF Fold 9/10 ...
# ✅ Done | Acc=0.8543 F1=0.4437 | fit=8.1s
# ➡️ RF Fold 10/10 ...
# ✅ Done | Acc=0.8645 F1=0.4985 | fit=7.7s
#
# ✅ Phase 1 | Data 4 | MLP | outer_folds=10
# ➡️ MLP Fold 1/10 ...
# ✅ Done | Acc=0.8388 F1=0.3438 | fit=4.3s
# ➡️ MLP Fold 2/10 ...
# ✅ Done | Acc=0.8521 F1=0.3117 | fit=3.2s
# ➡️ MLP Fold 3/10 ...
# ✅ Done | Acc=0.8396 F1=0.2470 | fit=4.1s
# ➡️ MLP Fold 4/10 ...
# ✅ Done | Acc=0.8513 F1=0.3090 | fit=3.9s
# ➡️ MLP Fold 5/10 ...
# ✅ Done | Acc=0.8490 F1=0.3347 | fit=3.0s
# ➡️ MLP Fold 6/10 ...
# ✅ Done | Acc=0.8427 F1=0.2933 | fit=4.3s
# ➡️ MLP Fold 7/10 ...
# ✅ Done | Acc=0.8396 F1=0.3101 | fit=5.2s
# ➡️ MLP Fold 8/10 ...
# ✅ Done | Acc=0.8474 F1=0.3217 | fit=3.8s
# ➡️ MLP Fold 9/10 ...
# ✅ Done | Acc=0.8426 F1=0.3159 | fit=4.4s
# ➡️ MLP Fold 10/10 ...
# ✅ Done | Acc=0.8426 F1=0.3534 | fit=3.8s
# ✅ Saved checkpoint: Results_BEFORE_filled.xlsx
#
# ================ PHASE 1 | DATA 5 ================
#
# ✅ Phase 1 | Data 5 | SVM | outer_folds=10
# ➡️ SVM Fold 1/10 ...
# ✅ Done | Acc=0.9828 F1=0.9820 | fit=0.6s
# ➡️ SVM Fold 2/10 ...
# ✅ Done | Acc=0.9781 F1=0.9767 | fit=0.5s
# ➡️ SVM Fold 3/10 ...
# ✅ Done | Acc=0.9836 F1=0.9828 | fit=0.6s
# ➡️ SVM Fold 4/10 ...
# ✅ Done | Acc=0.9781 F1=0.9577 | fit=0.5s
# ➡️ SVM Fold 5/10 ...
# ✅ Done | Acc=0.9804 F1=0.9653 | fit=0.5s
# ➡️ SVM Fold 6/10 ...
# ✅ Done | Acc=0.9812 F1=0.9801 | fit=0.8s
# ➡️ SVM Fold 7/10 ...
# ✅ Done | Acc=0.9867 F1=0.9658 | fit=0.6s
# ➡️ SVM Fold 8/10 ...
# ✅ Done | Acc=0.9773 F1=0.9726 | fit=0.6s
# ➡️ SVM Fold 9/10 ...
# ✅ Done | Acc=0.9804 F1=0.9598 | fit=0.6s
# ➡️ SVM Fold 10/10 ...
# ✅ Done | Acc=0.9820 F1=0.9748 | fit=0.6s
#
# ✅ Phase 1 | Data 5 | KNN | outer_folds=10
# ➡️ KNN Fold 1/10 ...
# ✅ Done | Acc=0.9867 F1=0.9803 | fit=2.0s
# ➡️ KNN Fold 2/10 ...
# ✅ Done | Acc=0.9828 F1=0.9730 | fit=2.0s
# ➡️ KNN Fold 3/10 ...
# ✅ Done | Acc=0.9875 F1=0.9778 | fit=2.0s
# ➡️ KNN Fold 4/10 ...
# ✅ Done | Acc=0.9867 F1=0.9676 | fit=2.0s
# ➡️ KNN Fold 5/10 ...
# ✅ Done | Acc=0.9890 F1=0.9590 | fit=2.0s
# ➡️ KNN Fold 6/10 ...
# ✅ Done | Acc=0.9875 F1=0.9845 | fit=2.0s
# ➡️ KNN Fold 7/10 ...
# ✅ Done | Acc=0.9906 F1=0.9543 | fit=2.0s
# ➡️ KNN Fold 8/10 ...
# ✅ Done | Acc=0.9844 F1=0.9776 | fit=2.0s
# ➡️ KNN Fold 9/10 ...
# ✅ Done | Acc=0.9836 F1=0.9424 | fit=2.0s
# ➡️ KNN Fold 10/10 ...
# ✅ Done | Acc=0.9851 F1=0.9627 | fit=2.0s
#
# ✅ Phase 1 | Data 5 | DT | outer_folds=10
# ➡️ DT Fold 1/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 2/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 3/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 4/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 5/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 6/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 7/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 8/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 9/10 ...
# ✅ Done | Acc=0.9992 F1=0.9796 | fit=0.5s
# ➡️ DT Fold 10/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
#
# ✅ Phase 1 | Data 5 | RF | outer_folds=10
# ➡️ RF Fold 1/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.4s
# ➡️ RF Fold 2/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 3/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.4s
# ➡️ RF Fold 4/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 5/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.4s
# ➡️ RF Fold 6/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 7/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.4s
# ➡️ RF Fold 8/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 9/10 ...
# ✅ Done | Acc=0.9984 F1=0.9788 | fit=5.2s
# ➡️ RF Fold 10/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.4s
#
# ✅ Phase 1 | Data 5 | MLP | outer_folds=10
# ➡️ MLP Fold 1/10 ...
# ✅ Done | Acc=0.9797 F1=0.9755 | fit=10.0s
# ➡️ MLP Fold 2/10 ...
# ✅ Done | Acc=0.9789 F1=0.9656 | fit=9.5s
# ➡️ MLP Fold 3/10 ...
# ✅ Done | Acc=0.9820 F1=0.9783 | fit=10.0s
# ➡️ MLP Fold 4/10 ...
# ✅ Done | Acc=0.9875 F1=0.9680 | fit=9.6s
# ➡️ MLP Fold 5/10 ...
# ✅ Done | Acc=0.9851 F1=0.9676 | fit=8.7s
# ➡️ MLP Fold 6/10 ...
# ✅ Done | Acc=0.9844 F1=0.9808 | fit=8.6s
# ➡️ MLP Fold 7/10 ...
# ✅ Done | Acc=0.9898 F1=0.9661 | fit=10.3s
# ➡️ MLP Fold 8/10 ...
# ✅ Done | Acc=0.9804 F1=0.9762 | fit=8.7s
# ➡️ MLP Fold 9/10 ...
# ✅ Done | Acc=0.9804 F1=0.9535 | fit=9.8s
# ➡️ MLP Fold 10/10 ...
# ✅ Done | Acc=0.9945 F1=0.9945 | fit=10.7s
# ✅ Saved checkpoint: Results_BEFORE_filled.xlsx
#
# ================ PHASE 1 | DATA 6 ================
#
# ✅ Phase 1 | Data 6 | SVM | outer_folds=10
# ➡️ SVM Fold 1/10 ...
# ✅ Done | Acc=0.9820 F1=0.9811 | fit=1.2s
# ➡️ SVM Fold 2/10 ...
# ✅ Done | Acc=0.9797 F1=0.9785 | fit=1.0s
# ➡️ SVM Fold 3/10 ...
# ✅ Done | Acc=0.9875 F1=0.9871 | fit=1.2s
# ➡️ SVM Fold 4/10 ...
# ✅ Done | Acc=0.9789 F1=0.9586 | fit=1.0s
# ➡️ SVM Fold 5/10 ...
# ✅ Done | Acc=0.9812 F1=0.9662 | fit=1.0s
# ➡️ SVM Fold 6/10 ...
# ✅ Done | Acc=0.9836 F1=0.9827 | fit=1.2s
# ➡️ SVM Fold 7/10 ...
# ✅ Done | Acc=0.9875 F1=0.9666 | fit=0.8s
# ➡️ SVM Fold 8/10 ...
# ✅ Done | Acc=0.9781 F1=0.9735 | fit=1.2s
# ➡️ SVM Fold 9/10 ...
# ✅ Done | Acc=0.9804 F1=0.9598 | fit=1.2s
# ➡️ SVM Fold 10/10 ...
# ✅ Done | Acc=0.9851 F1=0.9782 | fit=1.3s
#
# ✅ Phase 1 | Data 6 | KNN | outer_folds=10
# ➡️ KNN Fold 1/10 ...
# ✅ Done | Acc=0.9867 F1=0.9803 | fit=2.0s
# ➡️ KNN Fold 2/10 ...
# ✅ Done | Acc=0.9828 F1=0.9700 | fit=2.0s
# ➡️ KNN Fold 3/10 ...
# ✅ Done | Acc=0.9890 F1=0.9795 | fit=2.0s
# ➡️ KNN Fold 4/10 ...
# ✅ Done | Acc=0.9859 F1=0.9668 | fit=2.0s
# ➡️ KNN Fold 5/10 ...
# ✅ Done | Acc=0.9875 F1=0.9574 | fit=2.0s
# ➡️ KNN Fold 6/10 ...
# ✅ Done | Acc=0.9875 F1=0.9845 | fit=2.0s
# ➡️ KNN Fold 7/10 ...
# ✅ Done | Acc=0.9906 F1=0.9543 | fit=2.0s
# ➡️ KNN Fold 8/10 ...
# ✅ Done | Acc=0.9851 F1=0.9784 | fit=2.0s
# ➡️ KNN Fold 9/10 ...
# ✅ Done | Acc=0.9836 F1=0.9424 | fit=2.0s
# ➡️ KNN Fold 10/10 ...
# ✅ Done | Acc=0.9859 F1=0.9635 | fit=2.0s
#
# ✅ Phase 1 | Data 6 | DT | outer_folds=10
# ➡️ DT Fold 1/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 2/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 3/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 4/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 5/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 6/10 ...
# ✅ Done | Acc=0.9992 F1=0.9846 | fit=0.5s
# ➡️ DT Fold 7/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 8/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 9/10 ...
# ✅ Done | Acc=0.9992 F1=0.9796 | fit=0.5s
# ➡️ DT Fold 10/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
#
# ✅ Phase 1 | Data 6 | RF | outer_folds=10
# ➡️ RF Fold 1/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 2/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 3/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.4s
# ➡️ RF Fold 4/10 ...
# ✅ Done | Acc=0.9992 F1=0.9992 | fit=5.4s
# ➡️ RF Fold 5/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.4s
# ➡️ RF Fold 6/10 ...
# ✅ Done | Acc=0.9992 F1=0.9992 | fit=5.2s
# ➡️ RF Fold 7/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 8/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.2s
# ➡️ RF Fold 9/10 ...
# ✅ Done | Acc=0.9992 F1=0.9796 | fit=5.2s
# ➡️ RF Fold 10/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.4s
#
# ✅ Phase 1 | Data 6 | MLP | outer_folds=10
# ➡️ MLP Fold 1/10 ...
# ✅ Done | Acc=0.9773 F1=0.9727 | fit=10.6s
# ➡️ MLP Fold 2/10 ...
# ✅ Done | Acc=0.9750 F1=0.9452 | fit=10.6s
# ➡️ MLP Fold 3/10 ...
# ✅ Done | Acc=0.9844 F1=0.9778 | fit=10.3s
# ➡️ MLP Fold 4/10 ...
# ✅ Done | Acc=0.9875 F1=0.9680 | fit=9.6s
# ➡️ MLP Fold 5/10 ...
# ✅ Done | Acc=0.9828 F1=0.9651 | fit=7.7s
# ➡️ MLP Fold 6/10 ...
# ✅ Done | Acc=0.9828 F1=0.9790 | fit=9.8s
# ➡️ MLP Fold 7/10 ...
# ✅ Done | Acc=0.9883 F1=0.9675 | fit=10.3s
# ➡️ MLP Fold 8/10 ...
# ✅ Done | Acc=0.9781 F1=0.9735 | fit=10.7s
# ➡️ MLP Fold 9/10 ...
# ✅ Done | Acc=0.9843 F1=0.9644 | fit=9.4s
# ➡️ MLP Fold 10/10 ...
# ✅ Done | Acc=0.9898 F1=0.9832 | fit=10.8s
# ✅ Saved checkpoint: Results_BEFORE_filled.xlsx
#
# ================ PHASE 1 | DATA 7 ================
#
# ✅ Phase 1 | Data 7 | SVM | outer_folds=10
# ➡️ SVM Fold 1/10 ...
# ✅ Done | Acc=0.9828 F1=0.9825 | fit=0.5s
# ➡️ SVM Fold 2/10 ...
# ✅ Done | Acc=0.9797 F1=0.9792 | fit=0.5s
# ➡️ SVM Fold 3/10 ...
# ✅ Done | Acc=0.9820 F1=0.9786 | fit=0.5s
# ➡️ SVM Fold 4/10 ...
# ✅ Done | Acc=0.9844 F1=0.9842 | fit=0.5s
# ➡️ SVM Fold 5/10 ...
# ✅ Done | Acc=0.9828 F1=0.7333 | fit=0.5s
# ➡️ SVM Fold 6/10 ...
# ✅ Done | Acc=0.9765 F1=0.9694 | fit=0.5s
# ➡️ SVM Fold 7/10 ...
# ✅ Done | Acc=0.9765 F1=0.7229 | fit=0.5s
# ➡️ SVM Fold 8/10 ...
# ✅ Done | Acc=0.9789 F1=0.9720 | fit=0.5s
# ➡️ SVM Fold 9/10 ...
# ✅ Done | Acc=0.9828 F1=0.7301 | fit=0.5s
# ➡️ SVM Fold 10/10 ...
# ✅ Done | Acc=0.9836 F1=0.7341 | fit=0.5s
#
# ✅ Phase 1 | Data 7 | KNN | outer_folds=10
# ➡️ KNN Fold 1/10 ...
# ✅ Done | Acc=0.9844 F1=0.7294 | fit=2.0s
# ➡️ KNN Fold 2/10 ...
# ✅ Done | Acc=0.9820 F1=0.7211 | fit=2.0s
# ➡️ KNN Fold 3/10 ...
# ✅ Done | Acc=0.9859 F1=0.7310 | fit=2.0s
# ➡️ KNN Fold 4/10 ...
# ✅ Done | Acc=0.9883 F1=0.9784 | fit=2.0s
# ➡️ KNN Fold 5/10 ...
# ✅ Done | Acc=0.9875 F1=0.7384 | fit=2.0s
# ➡️ KNN Fold 6/10 ...
# ✅ Done | Acc=0.9804 F1=0.9707 | fit=2.0s
# ➡️ KNN Fold 7/10 ...
# ✅ Done | Acc=0.9828 F1=0.7273 | fit=2.0s
# ➡️ KNN Fold 8/10 ...
# ✅ Done | Acc=0.9789 F1=0.7013 | fit=2.0s
# ➡️ KNN Fold 9/10 ...
# ✅ Done | Acc=0.9867 F1=0.7275 | fit=2.0s
# ➡️ KNN Fold 10/10 ...
# ✅ Done | Acc=0.9765 F1=0.7208 | fit=2.0s
#
# ✅ Phase 1 | Data 7 | DT | outer_folds=10
# ➡️ DT Fold 1/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 2/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 3/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 4/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 5/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 6/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 7/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 8/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 9/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
# ➡️ DT Fold 10/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=0.5s
#
# ✅ Phase 1 | Data 7 | RF | outer_folds=10
# ➡️ RF Fold 1/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.7s
# ➡️ RF Fold 2/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.9s
# ➡️ RF Fold 3/10 ...
# ✅ Done | Acc=0.9977 F1=0.9977 | fit=5.9s
# ➡️ RF Fold 4/10 ...
# ✅ Done | Acc=0.9984 F1=0.9985 | fit=5.7s
# ➡️ RF Fold 5/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.7s
# ➡️ RF Fold 6/10 ...
# ✅ Done | Acc=0.9984 F1=0.9985 | fit=5.7s
# ➡️ RF Fold 7/10 ...
# ✅ Done | Acc=0.9992 F1=0.7463 | fit=5.9s
# ➡️ RF Fold 8/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=5.7s
# ➡️ RF Fold 9/10 ...
# ✅ Done | Acc=0.9992 F1=0.9992 | fit=5.9s
# ➡️ RF Fold 10/10 ...
# ✅ Done | Acc=1.0000 F1=1.0000 | fit=6.0s
#
# ✅ Phase 1 | Data 7 | MLP | outer_folds=10
# ➡️ MLP Fold 1/10 ...
# ✅ Done | Acc=0.9797 F1=0.7303 | fit=10.4s
# ➡️ MLP Fold 2/10 ...
# ✅ Done | Acc=0.9797 F1=0.9734 | fit=9.3s
# ➡️ MLP Fold 3/10 ...
# ✅ Done | Acc=0.9844 F1=0.7318 | fit=9.1s
# ➡️ MLP Fold 4/10 ...
# ✅ Done | Acc=0.9851 F1=0.7327 | fit=9.9s
# ➡️ MLP Fold 5/10 ...
# ✅ Done | Acc=0.9844 F1=0.7314 | fit=10.0s
# ➡️ MLP Fold 6/10 ...
# ✅ Done | Acc=0.9687 F1=0.7000 | fit=9.2s
# ➡️ MLP Fold 7/10 ...
# ✅ Done | Acc=0.9773 F1=0.7238 | fit=10.0s
# ➡️ MLP Fold 8/10 ...
# ✅ Done | Acc=0.9703 F1=0.7009 | fit=9.5s
# ➡️ MLP Fold 9/10 ...
